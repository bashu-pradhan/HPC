# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
guess_1 = pd.read_csv('guess1.csv') 
guess_2 = pd.read_csv('guess2.csv') 
guess_3 = pd.read_csv('guess3.csv')
best_line = pd.read_csv('bestLine.csv')
plot_original = pd.read_csv('scatter.csv')

# %%
plt.scatter(plot_original.X, plot_original.Y)
plt.scatter(guess_1.X, guess_1.Y)

# %%
plt.scatter(plot_original.X, plot_original.Y)
plt.scatter(guess_2.X, guess_2.Y)

# %%
plt.scatter(plot_original.X, plot_original.Y)
plt.scatter(guess_3.X, guess_3.Y)

# %%
plt.scatter(plot_original.X, plot_original.Y)
plt.scatter(best_line.X, best_line.Y)

# %%
plt.scatter(plot_original.X, plot_original.Y)
plt.scatter(guess_1.X, guess_1.Y, color='red')
plt.scatter(guess_2.X, guess_2.Y, color='orange')
plt.scatter(guess_3.X, guess_3.Y, color='pink')
plt.scatter(best_line.X, best_line.Y, color='green')
